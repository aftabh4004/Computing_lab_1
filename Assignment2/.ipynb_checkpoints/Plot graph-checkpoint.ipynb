# %%
import string
import random
import matplotlib.pyplot as plt
import csv
import os

# %% [markdown]
# ## Generating input of size n

# %%
def generate_input(n, k):
    res = []
    for i in range(n):
        N = 7
 
        fname = ''.join(random.choices(string.ascii_lowercase , k=N))
        lname = ''.join(random.choices(string.ascii_lowercase , k=N))



        dd = "{:02d}".format(random.randint(1,28))
        mm = "{:02d}".format(random.randint(1,12))
        yyyy = "{:04d}".format(random.randint(1980,2022))

        row = dd + mm + yyyy + ' ' + fname + ' ' + lname + '\n'
        row = [str(row)]
        res += row
        
    return res

# %% [markdown]
# ## Running the Algo a for inputs from 100 to 1000

# %%
fp = open("plottime.csv", "w")
fp.write("n,k,Algo,time\n")
fp.close()

for n in range(100, 1000, 10):
    k = n//2
    fp = open("randominput.txt", "w")
    fp.write(str(str(n) + ' ' + str(k) + '\n'))
    res = generate_input(n, k)
    fp.writelines(res)
    fp.close()
    
    os.system("./app a randominput.txt")
# Out:
# output1.txt file written successfully!
# Clock time taken by the program: 0.004510
# output1.txt file written successfully!
# Clock time taken by the program: 0.003664
# output1.txt file written successfully!
# Clock time taken by the program: 0.003523
# output1.txt file written successfully!
# Clock time taken by the program: 0.003934
# output1.txt file written successfully!
# Clock time taken by the program: 0.005801
# output1.txt file written successfully!
# Clock time taken by the program: 0.004448
# output1.txt file written successfully!
# Clock time taken by the program: 0.005956
# output1.txt file written successfully!
# Clock time taken by the program: 0.006384
# output1.txt file written successfully!
# Clock time taken by the program: 0.006742
# output1.txt file written successfully!
# Clock time taken by the program: 0.006924
# output1.txt file written successfully!
# Clock time taken by the program: 0.008185
# output1.txt file written successfully!
# Clock time taken by the program: 0.008750
# output1.txt file written successfully!
# Clock time taken by the program: 0.009830
# output1.txt file written successfully!
# Clock time taken by the program: 0.010646
# output1.txt file written successfully!
# Clock time taken by the program: 0.011551
# output1.txt file written successfully!
# Clock time taken by the program: 0.012882
# output1.txt file written successfully!
# Clock time taken by the program: 0.013542
# output1.txt file written successfully!
# Clock time taken by the program: 0.016202
# output1.txt file written successfully!
# Clock time taken by the program: 0.016584
# output1.txt file written successfully!
# Clock time taken by the program: 0.017516
# output1.txt file written successfully!
# Clock time taken by the program: 0.018869
# output1.txt file written successfully!
# Clock time taken by the program: 0.019940
# output1.txt file written successfully!
# Clock time taken by the program: 0.021425
# output1.txt file written successfully!
# Clock time taken by the program: 0.023075
# output1.txt file written successfully!
# Clock time taken by the program: 0.023101
# output1.txt file written successfully!
# Clock time taken by the program: 0.027602
# output1.txt file written successfully!
# Clock time taken by the program: 0.027641
# output1.txt file written successfully!
# Clock time taken by the program: 0.030114
# output1.txt file written successfully!
# Clock time taken by the program: 0.031247
# output1.txt file written successfully!
# Clock time taken by the program: 0.033056
# output1.txt file written successfully!
# Clock time taken by the program: 0.038411
# output1.txt file written successfully!
# Clock time taken by the program: 0.036481
# output1.txt file written successfully!
# Clock time taken by the program: 0.038902
# output1.txt file written successfully!
# Clock time taken by the program: 0.040340
# output1.txt file written successfully!
# Clock time taken by the program: 0.042933
# output1.txt file written successfully!
# Clock time taken by the program: 0.047840
# output1.txt file written successfully!
# Clock time taken by the program: 0.048475
# output1.txt file written successfully!
# Clock time taken by the program: 0.053384
# output1.txt file written successfully!
# Clock time taken by the program: 0.053134
# output1.txt file written successfully!
# Clock time taken by the program: 0.058403
# output1.txt file written successfully!
# Clock time taken by the program: 0.058030
# output1.txt file written successfully!
# Clock time taken by the program: 0.060628
# output1.txt file written successfully!
# Clock time taken by the program: 0.065050
# output1.txt file written successfully!
# Clock time taken by the program: 0.067270
# output1.txt file written successfully!
# Clock time taken by the program: 0.068851
# output1.txt file written successfully!
# Clock time taken by the program: 0.074132
# output1.txt file written successfully!
# Clock time taken by the program: 0.074837
# output1.txt file written successfully!
# Clock time taken by the program: 0.078508
# output1.txt file written successfully!
# Clock time taken by the program: 0.079598
# output1.txt file written successfully!
# Clock time taken by the program: 0.084794
# output1.txt file written successfully!
# Clock time taken by the program: 0.088207
# output1.txt file written successfully!
# Clock time taken by the program: 0.095852
# output1.txt file written successfully!
# Clock time taken by the program: 0.111753
# output1.txt file written successfully!
# Clock time taken by the program: 0.112533
# output1.txt file written successfully!
# Clock time taken by the program: 0.111460
# output1.txt file written successfully!
# Clock time taken by the program: 0.110737
# output1.txt file written successfully!
# Clock time taken by the program: 0.124851
# output1.txt file written successfully!
# Clock time taken by the program: 0.132667
# output1.txt file written successfully!
# Clock time taken by the program: 0.119190
# output1.txt file written successfully!
# Clock time taken by the program: 0.128471
# output1.txt file written successfully!
# Clock time taken by the program: 0.137323
# output1.txt file written successfully!
# Clock time taken by the program: 0.138302
# output1.txt file written successfully!
# Clock time taken by the program: 0.141444
# output1.txt file written successfully!
# Clock time taken by the program: 0.140940
# output1.txt file written successfully!
# Clock time taken by the program: 0.156545
# output1.txt file written successfully!
# Clock time taken by the program: 0.157881
# output1.txt file written successfully!
# Clock time taken by the program: 0.155437
# output1.txt file written successfully!
# Clock time taken by the program: 0.168243
# output1.txt file written successfully!
# Clock time taken by the program: 0.155380
# output1.txt file written successfully!
# Clock time taken by the program: 0.165881
# output1.txt file written successfully!
# Clock time taken by the program: 0.181394
# output1.txt file written successfully!
# Clock time taken by the program: 0.189481
# output1.txt file written successfully!
# Clock time taken by the program: 0.183413
# output1.txt file written successfully!
# Clock time taken by the program: 0.197222
# output1.txt file written successfully!
# Clock time taken by the program: 0.206003
# output1.txt file written successfully!
# Clock time taken by the program: 0.213492
# output1.txt file written successfully!
# Clock time taken by the program: 0.156572
# output1.txt file written successfully!
# Clock time taken by the program: 0.151379
# output1.txt file written successfully!
# Clock time taken by the program: 0.133086
# output1.txt file written successfully!
# Clock time taken by the program: 0.151675
# output1.txt file written successfully!
# Clock time taken by the program: 0.133238
# output1.txt file written successfully!
# Clock time taken by the program: 0.146999
# output1.txt file written successfully!
# Clock time taken by the program: 0.157331
# output1.txt file written successfully!
# Clock time taken by the program: 0.171836
# output1.txt file written successfully!
# Clock time taken by the program: 0.180521
# output1.txt file written successfully!
# Clock time taken by the program: 0.171455
# output1.txt file written successfully!
# Clock time taken by the program: 0.197051
# output1.txt file written successfully!
# Clock time taken by the program: 0.166700
# output1.txt file written successfully!
# Clock time taken by the program: 0.168450
# output1.txt file written successfully!
# Clock time taken by the program: 0.163687

# %% [markdown]
# ## Ploting input size VS time for algo a, O(n^2log(n))

# %%
x = []
y = []
  
with open('plottime.csv','r') as csvfile:
    plots = csv.reader(csvfile, delimiter = ',')
    plots = list(plots)
    for row in plots[1:]:
        x.append(int(row[0]))
        y.append(float(row[3]))


plt.plot(x, y)
plt.title("Plot for Algo a")
plt.xlabel("Number of Students")
plt.ylabel("Time[sec]")
plt.show()

# %% [markdown]
# ## Running the Algo b for inputs from 100 to 1000

# %%
fp = open("plottime.csv", "w")
fp.write("n,k,Algo,time\n")
fp.close()

for n in range(100, 1000, 10):
    k = n//2
    fp = open("randominput.txt", "w")
    fp.write(str(str(n) + ' ' + str(k) + '\n'))
    res = generate_input(n, k)
    fp.writelines(res)
    fp.close()
    
    os.system("./app b randominput.txt")
# Out:
# output2.txt file written successfully!
# Clock time taken by the program: 0.001015
# output2.txt file written successfully!
# Clock time taken by the program: 0.000897
# output2.txt file written successfully!
# Clock time taken by the program: 0.000720
# output2.txt file written successfully!
# Clock time taken by the program: 0.000731
# output2.txt file written successfully!
# Clock time taken by the program: 0.000709
# output2.txt file written successfully!
# Clock time taken by the program: 0.000821
# output2.txt file written successfully!
# Clock time taken by the program: 0.000868
# output2.txt file written successfully!
# Clock time taken by the program: 0.000816
# output2.txt file written successfully!
# Clock time taken by the program: 0.000829
# output2.txt file written successfully!
# Clock time taken by the program: 0.001006
# output2.txt file written successfully!
# Clock time taken by the program: 0.001060
# output2.txt file written successfully!
# Clock time taken by the program: 0.001174
# output2.txt file written successfully!
# Clock time taken by the program: 0.001162
# output2.txt file written successfully!
# Clock time taken by the program: 0.001294
# output2.txt file written successfully!
# Clock time taken by the program: 0.001117
# output2.txt file written successfully!
# Clock time taken by the program: 0.001292
# output2.txt file written successfully!
# Clock time taken by the program: 0.001323
# output2.txt file written successfully!
# Clock time taken by the program: 0.001312
# output2.txt file written successfully!
# Clock time taken by the program: 0.001353
# output2.txt file written successfully!
# Clock time taken by the program: 0.001322
# output2.txt file written successfully!
# Clock time taken by the program: 0.001468
# output2.txt file written successfully!
# Clock time taken by the program: 0.001452
# output2.txt file written successfully!
# Clock time taken by the program: 0.001489
# output2.txt file written successfully!
# Clock time taken by the program: 0.001548
# output2.txt file written successfully!
# Clock time taken by the program: 0.001630
# output2.txt file written successfully!
# Clock time taken by the program: 0.001646
# output2.txt file written successfully!
# Clock time taken by the program: 0.001658
# output2.txt file written successfully!
# Clock time taken by the program: 0.001690
# output2.txt file written successfully!
# Clock time taken by the program: 0.001766
# output2.txt file written successfully!
# Clock time taken by the program: 0.001805
# output2.txt file written successfully!
# Clock time taken by the program: 0.001811
# output2.txt file written successfully!
# Clock time taken by the program: 0.002110
# output2.txt file written successfully!
# Clock time taken by the program: 0.002023
# output2.txt file written successfully!
# Clock time taken by the program: 0.001999
# output2.txt file written successfully!
# Clock time taken by the program: 0.002135
# output2.txt file written successfully!
# Clock time taken by the program: 0.002031
# output2.txt file written successfully!
# Clock time taken by the program: 0.002160
# output2.txt file written successfully!
# Clock time taken by the program: 0.002216
# output2.txt file written successfully!
# Clock time taken by the program: 0.002133
# output2.txt file written successfully!
# Clock time taken by the program: 0.002258
# output2.txt file written successfully!
# Clock time taken by the program: 0.002256
# output2.txt file written successfully!
# Clock time taken by the program: 0.002327
# output2.txt file written successfully!
# Clock time taken by the program: 0.002351
# output2.txt file written successfully!
# Clock time taken by the program: 0.002470
# output2.txt file written successfully!
# Clock time taken by the program: 0.002385
# output2.txt file written successfully!
# Clock time taken by the program: 0.002415
# output2.txt file written successfully!
# Clock time taken by the program: 0.002480
# output2.txt file written successfully!
# Clock time taken by the program: 0.002619
# output2.txt file written successfully!
# Clock time taken by the program: 0.002611
# output2.txt file written successfully!
# Clock time taken by the program: 0.002701
# output2.txt file written successfully!
# Clock time taken by the program: 0.002685
# output2.txt file written successfully!
# Clock time taken by the program: 0.002750
# output2.txt file written successfully!
# Clock time taken by the program: 0.002729
# output2.txt file written successfully!
# Clock time taken by the program: 0.002683
# output2.txt file written successfully!
# Clock time taken by the program: 0.002890
# output2.txt file written successfully!
# Clock time taken by the program: 0.002830
# output2.txt file written successfully!
# Clock time taken by the program: 0.002897
# output2.txt file written successfully!
# Clock time taken by the program: 0.003150
# output2.txt file written successfully!
# Clock time taken by the program: 0.003002
# output2.txt file written successfully!
# Clock time taken by the program: 0.003039
# output2.txt file written successfully!
# Clock time taken by the program: 0.003095
# output2.txt file written successfully!
# Clock time taken by the program: 0.003198
# output2.txt file written successfully!
# Clock time taken by the program: 0.003254
# output2.txt file written successfully!
# Clock time taken by the program: 0.003271
# output2.txt file written successfully!
# Clock time taken by the program: 0.003472
# output2.txt file written successfully!
# Clock time taken by the program: 0.003238
# output2.txt file written successfully!
# Clock time taken by the program: 0.003368
# output2.txt file written successfully!
# Clock time taken by the program: 0.003389
# output2.txt file written successfully!
# Clock time taken by the program: 0.003632
# output2.txt file written successfully!
# Clock time taken by the program: 0.003551
# output2.txt file written successfully!
# Clock time taken by the program: 0.003529
# output2.txt file written successfully!
# Clock time taken by the program: 0.003583
# output2.txt file written successfully!
# Clock time taken by the program: 0.003609
# output2.txt file written successfully!
# Clock time taken by the program: 0.003659
# output2.txt file written successfully!
# Clock time taken by the program: 0.003580
# output2.txt file written successfully!
# Clock time taken by the program: 0.003834
# output2.txt file written successfully!
# Clock time taken by the program: 0.003807
# output2.txt file written successfully!
# Clock time taken by the program: 0.003901
# output2.txt file written successfully!
# Clock time taken by the program: 0.004038
# output2.txt file written successfully!
# Clock time taken by the program: 0.003996
# output2.txt file written successfully!
# Clock time taken by the program: 0.004140
# output2.txt file written successfully!
# Clock time taken by the program: 0.003857
# output2.txt file written successfully!
# Clock time taken by the program: 0.004042
# output2.txt file written successfully!
# Clock time taken by the program: 0.004229
# output2.txt file written successfully!
# Clock time taken by the program: 0.004218
# output2.txt file written successfully!
# Clock time taken by the program: 0.004338
# output2.txt file written successfully!
# Clock time taken by the program: 0.004299
# output2.txt file written successfully!
# Clock time taken by the program: 0.004210
# output2.txt file written successfully!
# Clock time taken by the program: 0.004558
# output2.txt file written successfully!
# Clock time taken by the program: 0.004378
# output2.txt file written successfully!
# Clock time taken by the program: 0.004487
# output2.txt file written successfully!
# Clock time taken by the program: 0.004586
# output2.txt file written successfully!
# Clock time taken by the program: 0.004520
# output2.txt file written successfully!
# Clock time taken by the program: 0.004462
# output2.txt file written successfully!
# Clock time taken by the program: 0.004507
# output2.txt file written successfully!
# Clock time taken by the program: 0.005297
# output2.txt file written successfully!
# Clock time taken by the program: 0.004833
# output2.txt file written successfully!
# Clock time taken by the program: 0.004548
# output2.txt file written successfully!
# Clock time taken by the program: 0.004685
# output2.txt file written successfully!
# Clock time taken by the program: 0.004736
# output2.txt file written successfully!
# Clock time taken by the program: 0.004777
# output2.txt file written successfully!
# Clock time taken by the program: 0.004903
# output2.txt file written successfully!
# Clock time taken by the program: 0.004915
# output2.txt file written successfully!
# Clock time taken by the program: 0.005083
# output2.txt file written successfully!
# Clock time taken by the program: 0.005011
# output2.txt file written successfully!
# Clock time taken by the program: 0.005183
# output2.txt file written successfully!
# Clock time taken by the program: 0.005181
# output2.txt file written successfully!
# Clock time taken by the program: 0.005464
# output2.txt file written successfully!
# Clock time taken by the program: 0.005114
# output2.txt file written successfully!
# Clock time taken by the program: 0.005668
# output2.txt file written successfully!
# Clock time taken by the program: 0.007671
# output2.txt file written successfully!
# Clock time taken by the program: 0.005541
# output2.txt file written successfully!
# Clock time taken by the program: 0.005675
# output2.txt file written successfully!
# Clock time taken by the program: 0.005142
# output2.txt file written successfully!
# Clock time taken by the program: 0.005420
# output2.txt file written successfully!
# Clock time taken by the program: 0.005582
# output2.txt file written successfully!
# Clock time taken by the program: 0.005881
# output2.txt file written successfully!
# Clock time taken by the program: 0.005961
# output2.txt file written successfully!
# Clock time taken by the program: 0.007169
# output2.txt file written successfully!
# Clock time taken by the program: 0.005792
# output2.txt file written successfully!
# Clock time taken by the program: 0.005833
# output2.txt file written successfully!
# Clock time taken by the program: 0.006290
# output2.txt file written successfully!
# Clock time taken by the program: 0.006155
# output2.txt file written successfully!
# Clock time taken by the program: 0.006027
# output2.txt file written successfully!
# Clock time taken by the program: 0.006077
# output2.txt file written successfully!
# Clock time taken by the program: 0.005955
# output2.txt file written successfully!
# Clock time taken by the program: 0.005923
# output2.txt file written successfully!
# Clock time taken by the program: 0.005973
# output2.txt file written successfully!
# Clock time taken by the program: 0.006002
# output2.txt file written successfully!
# Clock time taken by the program: 0.006181
# output2.txt file written successfully!
# Clock time taken by the program: 0.006109
# output2.txt file written successfully!
# Clock time taken by the program: 0.006065
# output2.txt file written successfully!
# Clock time taken by the program: 0.006361
# output2.txt file written successfully!
# Clock time taken by the program: 0.006130
# output2.txt file written successfully!
# Clock time taken by the program: 0.006507
# output2.txt file written successfully!
# Clock time taken by the program: 0.006332
# output2.txt file written successfully!
# Clock time taken by the program: 0.006707
# output2.txt file written successfully!
# Clock time taken by the program: 0.006413
# output2.txt file written successfully!
# Clock time taken by the program: 0.006115
# output2.txt file written successfully!
# Clock time taken by the program: 0.006693
# output2.txt file written successfully!
# Clock time taken by the program: 0.006725
# output2.txt file written successfully!
# Clock time taken by the program: 0.006636
# output2.txt file written successfully!
# Clock time taken by the program: 0.006578
# output2.txt file written successfully!
# Clock time taken by the program: 0.006985
# output2.txt file written successfully!
# Clock time taken by the program: 0.006925
# output2.txt file written successfully!
# Clock time taken by the program: 0.006713
# output2.txt file written successfully!
# Clock time taken by the program: 0.006786
# output2.txt file written successfully!
# Clock time taken by the program: 0.006715
# output2.txt file written successfully!
# Clock time taken by the program: 0.007076
# output2.txt file written successfully!
# Clock time taken by the program: 0.007065
# output2.txt file written successfully!
# Clock time taken by the program: 0.007079
# output2.txt file written successfully!
# Clock time taken by the program: 0.006911
# output2.txt file written successfully!
# Clock time taken by the program: 0.007067
# output2.txt file written successfully!
# Clock time taken by the program: 0.007271
# output2.txt file written successfully!
# Clock time taken by the program: 0.007283
# output2.txt file written successfully!
# Clock time taken by the program: 0.007347
# output2.txt file written successfully!
# Clock time taken by the program: 0.007174
# output2.txt file written successfully!
# Clock time taken by the program: 0.007267
# output2.txt file written successfully!
# Clock time taken by the program: 0.007088
# output2.txt file written successfully!
# Clock time taken by the program: 0.007213
# output2.txt file written successfully!
# Clock time taken by the program: 0.007459
# output2.txt file written successfully!
# Clock time taken by the program: 0.007413
# output2.txt file written successfully!
# Clock time taken by the program: 0.007553
# output2.txt file written successfully!
# Clock time taken by the program: 0.007476
# output2.txt file written successfully!
# Clock time taken by the program: 0.007616
# output2.txt file written successfully!
# Clock time taken by the program: 0.007683
# output2.txt file written successfully!
# Clock time taken by the program: 0.007627
# output2.txt file written successfully!
# Clock time taken by the program: 0.007789
# output2.txt file written successfully!
# Clock time taken by the program: 0.007975
# output2.txt file written successfully!
# Clock time taken by the program: 0.007895
# output2.txt file written successfully!
# Clock time taken by the program: 0.007981
# output2.txt file written successfully!
# Clock time taken by the program: 0.007936
# output2.txt file written successfully!
# Clock time taken by the program: 0.008633
# output2.txt file written successfully!
# Clock time taken by the program: 0.008177
# output2.txt file written successfully!
# Clock time taken by the program: 0.007875
# output2.txt file written successfully!
# Clock time taken by the program: 0.007960
# output2.txt file written successfully!
# Clock time taken by the program: 0.008182
# output2.txt file written successfully!
# Clock time taken by the program: 0.008165
# output2.txt file written successfully!
# Clock time taken by the program: 0.008097
# output2.txt file written successfully!
# Clock time taken by the program: 0.008430
# output2.txt file written successfully!
# Clock time taken by the program: 0.008449
# output2.txt file written successfully!
# Clock time taken by the program: 0.008319
# output2.txt file written successfully!
# Clock time taken by the program: 0.008424
# output2.txt file written successfully!
# Clock time taken by the program: 0.008363
# output2.txt file written successfully!
# Clock time taken by the program: 0.009365
# output2.txt file written successfully!
# Clock time taken by the program: 0.008588
# output2.txt file written successfully!
# Clock time taken by the program: 0.008708
# output2.txt file written successfully!
# Clock time taken by the program: 0.008654
# output2.txt file written successfully!
# Clock time taken by the program: 0.008525
# output2.txt file written successfully!
# Clock time taken by the program: 0.008718
# output2.txt file written successfully!
# Clock time taken by the program: 0.008908
# output2.txt file written successfully!
# Clock time taken by the program: 0.008686
# output2.txt file written successfully!
# Clock time taken by the program: 0.008909
# output2.txt file written successfully!
# Clock time taken by the program: 0.008825
# output2.txt file written successfully!
# Clock time taken by the program: 0.008663
# output2.txt file written successfully!
# Clock time taken by the program: 0.008795
# output2.txt file written successfully!
# Clock time taken by the program: 0.009089
# output2.txt file written successfully!
# Clock time taken by the program: 0.008970
# output2.txt file written successfully!
# Clock time taken by the program: 0.008815
# output2.txt file written successfully!
# Clock time taken by the program: 0.009026
# output2.txt file written successfully!
# Clock time taken by the program: 0.009255
# output2.txt file written successfully!
# Clock time taken by the program: 0.009046
# output2.txt file written successfully!
# Clock time taken by the program: 0.009196
# output2.txt file written successfully!
# Clock time taken by the program: 0.009410
# output2.txt file written successfully!
# Clock time taken by the program: 0.009947
# output2.txt file written successfully!
# Clock time taken by the program: 0.007065
# output2.txt file written successfully!
# Clock time taken by the program: 0.009225
# output2.txt file written successfully!
# Clock time taken by the program: 0.009428
# output2.txt file written successfully!
# Clock time taken by the program: 0.007321
# output2.txt file written successfully!
# Clock time taken by the program: 0.009646
# output2.txt file written successfully!
# Clock time taken by the program: 0.009438
# output2.txt file written successfully!
# Clock time taken by the program: 0.009929
# output2.txt file written successfully!
# Clock time taken by the program: 0.009803
# output2.txt file written successfully!
# Clock time taken by the program: 0.009514
# output2.txt file written successfully!
# Clock time taken by the program: 0.009737
# output2.txt file written successfully!
# Clock time taken by the program: 0.010090
# output2.txt file written successfully!
# Clock time taken by the program: 0.009939
# output2.txt file written successfully!
# Clock time taken by the program: 0.009586
# output2.txt file written successfully!
# Clock time taken by the program: 0.010715
# output2.txt file written successfully!
# Clock time taken by the program: 0.009817
# output2.txt file written successfully!
# Clock time taken by the program: 0.009959
# output2.txt file written successfully!
# Clock time taken by the program: 0.010146
# output2.txt file written successfully!
# Clock time taken by the program: 0.010285
# output2.txt file written successfully!
# Clock time taken by the program: 0.010738
# output2.txt file written successfully!
# Clock time taken by the program: 0.010221
# output2.txt file written successfully!
# Clock time taken by the program: 0.010230
# output2.txt file written successfully!
# Clock time taken by the program: 0.010157
# output2.txt file written successfully!
# Clock time taken by the program: 0.010177
# output2.txt file written successfully!
# Clock time taken by the program: 0.011181
# output2.txt file written successfully!
# Clock time taken by the program: 0.010516
# output2.txt file written successfully!
# Clock time taken by the program: 0.010525
# output2.txt file written successfully!
# Clock time taken by the program: 0.010454
# output2.txt file written successfully!
# Clock time taken by the program: 0.010826
# output2.txt file written successfully!
# Clock time taken by the program: 0.010736
# output2.txt file written successfully!
# Clock time taken by the program: 0.010687
# output2.txt file written successfully!
# Clock time taken by the program: 0.010432
# output2.txt file written successfully!
# Clock time taken by the program: 0.010830
# output2.txt file written successfully!
# Clock time taken by the program: 0.010831
# output2.txt file written successfully!
# Clock time taken by the program: 0.011271
# output2.txt file written successfully!
# Clock time taken by the program: 0.011034
# output2.txt file written successfully!
# Clock time taken by the program: 0.011021
# output2.txt file written successfully!
# Clock time taken by the program: 0.010889
# output2.txt file written successfully!
# Clock time taken by the program: 0.010856
# output2.txt file written successfully!
# Clock time taken by the program: 0.010890
# output2.txt file written successfully!
# Clock time taken by the program: 0.011011
# output2.txt file written successfully!
# Clock time taken by the program: 0.011037
# output2.txt file written successfully!
# Clock time taken by the program: 0.011398
# output2.txt file written successfully!
# Clock time taken by the program: 0.011258
# output2.txt file written successfully!
# Clock time taken by the program: 0.011065
# output2.txt file written successfully!
# Clock time taken by the program: 0.011301
# output2.txt file written successfully!
# Clock time taken by the program: 0.011455
# output2.txt file written successfully!
# Clock time taken by the program: 0.011401
# output2.txt file written successfully!
# Clock time taken by the program: 0.011441
# output2.txt file written successfully!
# Clock time taken by the program: 0.011854
# output2.txt file written successfully!
# Clock time taken by the program: 0.011722
# output2.txt file written successfully!
# Clock time taken by the program: 0.011650
# output2.txt file written successfully!
# Clock time taken by the program: 0.011732
# output2.txt file written successfully!
# Clock time taken by the program: 0.011792
# output2.txt file written successfully!
# Clock time taken by the program: 0.011879
# output2.txt file written successfully!
# Clock time taken by the program: 0.011706
# output2.txt file written successfully!
# Clock time taken by the program: 0.011829
# output2.txt file written successfully!
# Clock time taken by the program: 0.012135
# output2.txt file written successfully!
# Clock time taken by the program: 0.012312
# output2.txt file written successfully!
# Clock time taken by the program: 0.012063
# output2.txt file written successfully!
# Clock time taken by the program: 0.012011
# output2.txt file written successfully!
# Clock time taken by the program: 0.012393
# output2.txt file written successfully!
# Clock time taken by the program: 0.012264
# output2.txt file written successfully!
# Clock time taken by the program: 0.012062
# output2.txt file written successfully!
# Clock time taken by the program: 0.013053
# output2.txt file written successfully!
# Clock time taken by the program: 0.012455
# output2.txt file written successfully!
# Clock time taken by the program: 0.012601
# output2.txt file written successfully!
# Clock time taken by the program: 0.012669
# output2.txt file written successfully!
# Clock time taken by the program: 0.012340
# output2.txt file written successfully!
# Clock time taken by the program: 0.012009
# output2.txt file written successfully!
# Clock time taken by the program: 0.012379
# output2.txt file written successfully!
# Clock time taken by the program: 0.012285
# output2.txt file written successfully!
# Clock time taken by the program: 0.013046
# output2.txt file written successfully!
# Clock time taken by the program: 0.013024
# output2.txt file written successfully!
# Clock time taken by the program: 0.013162
# output2.txt file written successfully!
# Clock time taken by the program: 0.012959
# output2.txt file written successfully!
# Clock time taken by the program: 0.013325
# output2.txt file written successfully!
# Clock time taken by the program: 0.013103
# output2.txt file written successfully!
# Clock time taken by the program: 0.012516
# output2.txt file written successfully!
# Clock time taken by the program: 0.013202
# output2.txt file written successfully!
# Clock time taken by the program: 0.013222
# output2.txt file written successfully!
# Clock time taken by the program: 0.012989
# output2.txt file written successfully!
# Clock time taken by the program: 0.013410
# output2.txt file written successfully!
# Clock time taken by the program: 0.013618
# output2.txt file written successfully!
# Clock time taken by the program: 0.012817
# output2.txt file written successfully!
# Clock time taken by the program: 0.013065
# output2.txt file written successfully!
# Clock time taken by the program: 0.012654
# output2.txt file written successfully!
# Clock time taken by the program: 0.014514
# output2.txt file written successfully!
# Clock time taken by the program: 0.014608
# output2.txt file written successfully!
# Clock time taken by the program: 0.012884
# output2.txt file written successfully!
# Clock time taken by the program: 0.013582
# output2.txt file written successfully!
# Clock time taken by the program: 0.014551
# output2.txt file written successfully!
# Clock time taken by the program: 0.013928
# output2.txt file written successfully!
# Clock time taken by the program: 0.013839
# output2.txt file written successfully!
# Clock time taken by the program: 0.013213
# output2.txt file written successfully!
# Clock time taken by the program: 0.013744
# output2.txt file written successfully!
# Clock time taken by the program: 0.014330
# output2.txt file written successfully!
# Clock time taken by the program: 0.013644
# output2.txt file written successfully!
# Clock time taken by the program: 0.013686
# output2.txt file written successfully!
# Clock time taken by the program: 0.013799
# output2.txt file written successfully!
# Clock time taken by the program: 0.013958
# output2.txt file written successfully!
# Clock time taken by the program: 0.014260
# output2.txt file written successfully!
# Clock time taken by the program: 0.013830
# output2.txt file written successfully!
# Clock time taken by the program: 0.014659
# output2.txt file written successfully!
# Clock time taken by the program: 0.014379
# output2.txt file written successfully!
# Clock time taken by the program: 0.014062
# output2.txt file written successfully!
# Clock time taken by the program: 0.013860
# output2.txt file written successfully!
# Clock time taken by the program: 0.015029
# output2.txt file written successfully!
# Clock time taken by the program: 0.013479
# output2.txt file written successfully!
# Clock time taken by the program: 0.013955
# output2.txt file written successfully!
# Clock time taken by the program: 0.014077
# output2.txt file written successfully!
# Clock time taken by the program: 0.014301
# output2.txt file written successfully!
# Clock time taken by the program: 0.014729
# output2.txt file written successfully!
# Clock time taken by the program: 0.014305
# output2.txt file written successfully!
# Clock time taken by the program: 0.014253
# output2.txt file written successfully!
# Clock time taken by the program: 0.015301
# output2.txt file written successfully!
# Clock time taken by the program: 0.015129
# output2.txt file written successfully!
# Clock time taken by the program: 0.013911
# output2.txt file written successfully!
# Clock time taken by the program: 0.014646
# output2.txt file written successfully!
# Clock time taken by the program: 0.013955
# output2.txt file written successfully!
# Clock time taken by the program: 0.014813
# output2.txt file written successfully!
# Clock time taken by the program: 0.012956
# output2.txt file written successfully!
# Clock time taken by the program: 0.013345
# output2.txt file written successfully!
# Clock time taken by the program: 0.015027
# output2.txt file written successfully!
# Clock time taken by the program: 0.014532
# output2.txt file written successfully!
# Clock time taken by the program: 0.014692
# output2.txt file written successfully!
# Clock time taken by the program: 0.014845
# output2.txt file written successfully!
# Clock time taken by the program: 0.014908
# output2.txt file written successfully!
# Clock time taken by the program: 0.014909
# output2.txt file written successfully!
# Clock time taken by the program: 0.015404
# output2.txt file written successfully!
# Clock time taken by the program: 0.014909
# output2.txt file written successfully!
# Clock time taken by the program: 0.015272
# output2.txt file written successfully!
# Clock time taken by the program: 0.014783
# output2.txt file written successfully!
# Clock time taken by the program: 0.015647
# output2.txt file written successfully!
# Clock time taken by the program: 0.015202
# output2.txt file written successfully!
# Clock time taken by the program: 0.015366
# output2.txt file written successfully!
# Clock time taken by the program: 0.015824
# output2.txt file written successfully!
# Clock time taken by the program: 0.015478
# output2.txt file written successfully!
# Clock time taken by the program: 0.015228
# output2.txt file written successfully!
# Clock time taken by the program: 0.015230
# output2.txt file written successfully!
# Clock time taken by the program: 0.015200
# output2.txt file written successfully!
# Clock time taken by the program: 0.015628
# output2.txt file written successfully!
# Clock time taken by the program: 0.015914
# output2.txt file written successfully!
# Clock time taken by the program: 0.016596
# output2.txt file written successfully!
# Clock time taken by the program: 0.016453
# output2.txt file written successfully!
# Clock time taken by the program: 0.016029
# output2.txt file written successfully!
# Clock time taken by the program: 0.016361
# output2.txt file written successfully!
# Clock time taken by the program: 0.016045
# output2.txt file written successfully!
# Clock time taken by the program: 0.016861
# output2.txt file written successfully!
# Clock time taken by the program: 0.016122
# output2.txt file written successfully!
# Clock time taken by the program: 0.016297
# output2.txt file written successfully!
# Clock time taken by the program: 0.016566
# output2.txt file written successfully!
# Clock time taken by the program: 0.016456
# output2.txt file written successfully!
# Clock time taken by the program: 0.016463
# output2.txt file written successfully!
# Clock time taken by the program: 0.016855
# output2.txt file written successfully!
# Clock time taken by the program: 0.016096
# output2.txt file written successfully!
# Clock time taken by the program: 0.016340
# output2.txt file written successfully!
# Clock time taken by the program: 0.016349
# output2.txt file written successfully!
# Clock time taken by the program: 0.015966
# output2.txt file written successfully!
# Clock time taken by the program: 0.016183
# output2.txt file written successfully!
# Clock time taken by the program: 0.016442
# output2.txt file written successfully!
# Clock time taken by the program: 0.017488
# output2.txt file written successfully!
# Clock time taken by the program: 0.016211
# output2.txt file written successfully!
# Clock time taken by the program: 0.016794
# output2.txt file written successfully!
# Clock time taken by the program: 0.016185
# output2.txt file written successfully!
# Clock time taken by the program: 0.016400
# output2.txt file written successfully!
# Clock time taken by the program: 0.016065
# output2.txt file written successfully!
# Clock time taken by the program: 0.016607
# output2.txt file written successfully!
# Clock time taken by the program: 0.016997
# output2.txt file written successfully!
# Clock time taken by the program: 0.016759
# output2.txt file written successfully!
# Clock time taken by the program: 0.016651
# output2.txt file written successfully!
# Clock time taken by the program: 0.016974
# output2.txt file written successfully!
# Clock time taken by the program: 0.016016
# output2.txt file written successfully!
# Clock time taken by the program: 0.017400
# output2.txt file written successfully!
# Clock time taken by the program: 0.016508
# output2.txt file written successfully!
# Clock time taken by the program: 0.016492
# output2.txt file written successfully!
# Clock time taken by the program: 0.017973
# output2.txt file written successfully!
# Clock time taken by the program: 0.018029
# output2.txt file written successfully!
# Clock time taken by the program: 0.017398
# output2.txt file written successfully!
# Clock time taken by the program: 0.017171
# output2.txt file written successfully!
# Clock time taken by the program: 0.017733
# output2.txt file written successfully!
# Clock time taken by the program: 0.017096
# output2.txt file written successfully!
# Clock time taken by the program: 0.017478
# output2.txt file written successfully!
# Clock time taken by the program: 0.017773
# output2.txt file written successfully!
# Clock time taken by the program: 0.017875
# output2.txt file written successfully!
# Clock time taken by the program: 0.017554
# output2.txt file written successfully!
# Clock time taken by the program: 0.017814
# output2.txt file written successfully!
# Clock time taken by the program: 0.018059
# output2.txt file written successfully!
# Clock time taken by the program: 0.017832
# output2.txt file written successfully!
# Clock time taken by the program: 0.017749
# output2.txt file written successfully!
# Clock time taken by the program: 0.017986
# output2.txt file written successfully!
# Clock time taken by the program: 0.018362
# output2.txt file written successfully!
# Clock time taken by the program: 0.018006
# output2.txt file written successfully!
# Clock time taken by the program: 0.017810
# output2.txt file written successfully!
# Clock time taken by the program: 0.018049
# output2.txt file written successfully!
# Clock time taken by the program: 0.017754
# output2.txt file written successfully!
# Clock time taken by the program: 0.017606
# output2.txt file written successfully!
# Clock time taken by the program: 0.014406
# output2.txt file written successfully!
# Clock time taken by the program: 0.017717
# output2.txt file written successfully!
# Clock time taken by the program: 0.018067
# output2.txt file written successfully!
# Clock time taken by the program: 0.018133
# output2.txt file written successfully!
# Clock time taken by the program: 0.018496
# output2.txt file written successfully!
# Clock time taken by the program: 0.018039
# output2.txt file written successfully!
# Clock time taken by the program: 0.018854
# output2.txt file written successfully!
# Clock time taken by the program: 0.017675
# output2.txt file written successfully!
# Clock time taken by the program: 0.018178
# output2.txt file written successfully!
# Clock time taken by the program: 0.018175
# output2.txt file written successfully!
# Clock time taken by the program: 0.018217
# output2.txt file written successfully!
# Clock time taken by the program: 0.019372
# output2.txt file written successfully!
# Clock time taken by the program: 0.019164
# output2.txt file written successfully!
# Clock time taken by the program: 0.019667
# output2.txt file written successfully!
# Clock time taken by the program: 0.018176
# output2.txt file written successfully!
# Clock time taken by the program: 0.018467
# output2.txt file written successfully!
# Clock time taken by the program: 0.018628
# output2.txt file written successfully!
# Clock time taken by the program: 0.020177
# output2.txt file written successfully!
# Clock time taken by the program: 0.019295
# output2.txt file written successfully!
# Clock time taken by the program: 0.019730
# output2.txt file written successfully!
# Clock time taken by the program: 0.018622
# output2.txt file written successfully!
# Clock time taken by the program: 0.018502
# output2.txt file written successfully!
# Clock time taken by the program: 0.019058
# output2.txt file written successfully!
# Clock time taken by the program: 0.023275
# output2.txt file written successfully!
# Clock time taken by the program: 0.021600
# output2.txt file written successfully!
# Clock time taken by the program: 0.020608
# output2.txt file written successfully!
# Clock time taken by the program: 0.018648
# output2.txt file written successfully!
# Clock time taken by the program: 0.019723
# output2.txt file written successfully!
# Clock time taken by the program: 0.018931
# output2.txt file written successfully!
# Clock time taken by the program: 0.019537
# output2.txt file written successfully!
# Clock time taken by the program: 0.019360
# output2.txt file written successfully!
# Clock time taken by the program: 0.019247
# output2.txt file written successfully!
# Clock time taken by the program: 0.019233
# output2.txt file written successfully!
# Clock time taken by the program: 0.019440
# output2.txt file written successfully!
# Clock time taken by the program: 0.019490
# output2.txt file written successfully!
# Clock time taken by the program: 0.020028
# output2.txt file written successfully!
# Clock time taken by the program: 0.021543
# output2.txt file written successfully!
# Clock time taken by the program: 0.021616
# output2.txt file written successfully!
# Clock time taken by the program: 0.020431
# output2.txt file written successfully!
# Clock time taken by the program: 0.020237
# output2.txt file written successfully!
# Clock time taken by the program: 0.021061
# output2.txt file written successfully!
# Clock time taken by the program: 0.020305
# output2.txt file written successfully!
# Clock time taken by the program: 0.019704
# output2.txt file written successfully!
# Clock time taken by the program: 0.022177
# output2.txt file written successfully!
# Clock time taken by the program: 0.020951
# output2.txt file written successfully!
# Clock time taken by the program: 0.021003
# output2.txt file written successfully!
# Clock time taken by the program: 0.020178
# output2.txt file written successfully!
# Clock time taken by the program: 0.020014
# output2.txt file written successfully!
# Clock time taken by the program: 0.020402
# output2.txt file written successfully!
# Clock time taken by the program: 0.020831
# output2.txt file written successfully!
# Clock time taken by the program: 0.020792
# output2.txt file written successfully!
# Clock time taken by the program: 0.021229
# output2.txt file written successfully!
# Clock time taken by the program: 0.021620
# output2.txt file written successfully!
# Clock time taken by the program: 0.020107
# output2.txt file written successfully!
# Clock time taken by the program: 0.019826
# output2.txt file written successfully!
# Clock time taken by the program: 0.020402
# output2.txt file written successfully!
# Clock time taken by the program: 0.025033
# output2.txt file written successfully!
# Clock time taken by the program: 0.021443
# output2.txt file written successfully!
# Clock time taken by the program: 0.021146
# output2.txt file written successfully!
# Clock time taken by the program: 0.021311
# output2.txt file written successfully!
# Clock time taken by the program: 0.021602
# output2.txt file written successfully!
# Clock time taken by the program: 0.021194
# output2.txt file written successfully!
# Clock time taken by the program: 0.020768
# output2.txt file written successfully!
# Clock time taken by the program: 0.021117
# output2.txt file written successfully!
# Clock time taken by the program: 0.021533
# output2.txt file written successfully!
# Clock time taken by the program: 0.021308
# output2.txt file written successfully!
# Clock time taken by the program: 0.020881
# output2.txt file written successfully!
# Clock time taken by the program: 0.021929
# output2.txt file written successfully!
# Clock time taken by the program: 0.021906
# output2.txt file written successfully!
# Clock time taken by the program: 0.021704
# output2.txt file written successfully!
# Clock time taken by the program: 0.020959
# output2.txt file written successfully!
# Clock time taken by the program: 0.021947
# output2.txt file written successfully!
# Clock time taken by the program: 0.022438
# output2.txt file written successfully!
# Clock time taken by the program: 0.021497
# output2.txt file written successfully!
# Clock time taken by the program: 0.023035
# output2.txt file written successfully!
# Clock time taken by the program: 0.024320
# output2.txt file written successfully!
# Clock time taken by the program: 0.022130
# output2.txt file written successfully!
# Clock time taken by the program: 0.022319
# output2.txt file written successfully!
# Clock time taken by the program: 0.022281
# output2.txt file written successfully!
# Clock time taken by the program: 0.021946
# output2.txt file written successfully!
# Clock time taken by the program: 0.022706
# output2.txt file written successfully!
# Clock time taken by the program: 0.022178
# output2.txt file written successfully!
# Clock time taken by the program: 0.021106
# output2.txt file written successfully!
# Clock time taken by the program: 0.022286
# output2.txt file written successfully!
# Clock time taken by the program: 0.022484
# output2.txt file written successfully!
# Clock time taken by the program: 0.023314
# output2.txt file written successfully!
# Clock time taken by the program: 0.022035
# output2.txt file written successfully!
# Clock time taken by the program: 0.021072
# output2.txt file written successfully!
# Clock time taken by the program: 0.022263
# output2.txt file written successfully!
# Clock time taken by the program: 0.022476
# output2.txt file written successfully!
# Clock time taken by the program: 0.024030
# output2.txt file written successfully!
# Clock time taken by the program: 0.024315
# output2.txt file written successfully!
# Clock time taken by the program: 0.021724
# output2.txt file written successfully!
# Clock time taken by the program: 0.022260
# output2.txt file written successfully!
# Clock time taken by the program: 0.024802
# output2.txt file written successfully!
# Clock time taken by the program: 0.023029
# output2.txt file written successfully!
# Clock time taken by the program: 0.023796
# output2.txt file written successfully!
# Clock time taken by the program: 0.022643
# output2.txt file written successfully!
# Clock time taken by the program: 0.022495
# output2.txt file written successfully!
# Clock time taken by the program: 0.022238
# output2.txt file written successfully!
# Clock time taken by the program: 0.022378
# output2.txt file written successfully!
# Clock time taken by the program: 0.022315
# output2.txt file written successfully!
# Clock time taken by the program: 0.023419
# output2.txt file written successfully!
# Clock time taken by the program: 0.023627
# output2.txt file written successfully!
# Clock time taken by the program: 0.024647
# output2.txt file written successfully!
# Clock time taken by the program: 0.022686
# output2.txt file written successfully!
# Clock time taken by the program: 0.023768
# output2.txt file written successfully!
# Clock time taken by the program: 0.023826
# output2.txt file written successfully!
# Clock time taken by the program: 0.023682
# output2.txt file written successfully!
# Clock time taken by the program: 0.022995
# output2.txt file written successfully!
# Clock time taken by the program: 0.025794
# output2.txt file written successfully!
# Clock time taken by the program: 0.022870
# output2.txt file written successfully!
# Clock time taken by the program: 0.022852
# output2.txt file written successfully!
# Clock time taken by the program: 0.022813
# output2.txt file written successfully!
# Clock time taken by the program: 0.024788
# output2.txt file written successfully!
# Clock time taken by the program: 0.024107
# output2.txt file written successfully!
# Clock time taken by the program: 0.023223
# output2.txt file written successfully!
# Clock time taken by the program: 0.023190
# output2.txt file written successfully!
# Clock time taken by the program: 0.024670
# output2.txt file written successfully!
# Clock time taken by the program: 0.024710
# output2.txt file written successfully!
# Clock time taken by the program: 0.024071
# output2.txt file written successfully!
# Clock time taken by the program: 0.024546
# output2.txt file written successfully!
# Clock time taken by the program: 0.024151
# output2.txt file written successfully!
# Clock time taken by the program: 0.023249
# output2.txt file written successfully!
# Clock time taken by the program: 0.023650
# output2.txt file written successfully!
# Clock time taken by the program: 0.022897
# output2.txt file written successfully!
# Clock time taken by the program: 0.024024
# output2.txt file written successfully!
# Clock time taken by the program: 0.023266
# output2.txt file written successfully!
# Clock time taken by the program: 0.023935
# output2.txt file written successfully!
# Clock time taken by the program: 0.023951
# output2.txt file written successfully!
# Clock time taken by the program: 0.023827
# output2.txt file written successfully!
# Clock time taken by the program: 0.024214
# output2.txt file written successfully!
# Clock time taken by the program: 0.023375
# output2.txt file written successfully!
# Clock time taken by the program: 0.023344
# output2.txt file written successfully!
# Clock time taken by the program: 0.023930
# output2.txt file written successfully!
# Clock time taken by the program: 0.023412
# output2.txt file written successfully!
# Clock time taken by the program: 0.024036
# output2.txt file written successfully!
# Clock time taken by the program: 0.024411
# output2.txt file written successfully!
# Clock time taken by the program: 0.023878
# output2.txt file written successfully!
# Clock time taken by the program: 0.024018
# output2.txt file written successfully!
# Clock time taken by the program: 0.023945
# output2.txt file written successfully!
# Clock time taken by the program: 0.024067
# output2.txt file written successfully!
# Clock time taken by the program: 0.025436
# output2.txt file written successfully!
# Clock time taken by the program: 0.024301
# output2.txt file written successfully!
# Clock time taken by the program: 0.024424
# output2.txt file written successfully!
# Clock time taken by the program: 0.023957
# output2.txt file written successfully!
# Clock time taken by the program: 0.025006
# output2.txt file written successfully!
# Clock time taken by the program: 0.024471
# output2.txt file written successfully!
# Clock time taken by the program: 0.025221
# output2.txt file written successfully!
# Clock time taken by the program: 0.024574
# output2.txt file written successfully!
# Clock time taken by the program: 0.024209
# output2.txt file written successfully!
# Clock time taken by the program: 0.024762
# output2.txt file written successfully!
# Clock time taken by the program: 0.024472
# output2.txt file written successfully!
# Clock time taken by the program: 0.024911
# output2.txt file written successfully!
# Clock time taken by the program: 0.024985
# output2.txt file written successfully!
# Clock time taken by the program: 0.024794
# output2.txt file written successfully!
# Clock time taken by the program: 0.025191
# output2.txt file written successfully!
# Clock time taken by the program: 0.025095
# output2.txt file written successfully!
# Clock time taken by the program: 0.025193
# output2.txt file written successfully!
# Clock time taken by the program: 0.025281
# output2.txt file written successfully!
# Clock time taken by the program: 0.026182
# output2.txt file written successfully!
# Clock time taken by the program: 0.024833
# output2.txt file written successfully!
# Clock time taken by the program: 0.025749
# output2.txt file written successfully!
# Clock time taken by the program: 0.025278
# output2.txt file written successfully!
# Clock time taken by the program: 0.027060
# output2.txt file written successfully!
# Clock time taken by the program: 0.025488
# output2.txt file written successfully!
# Clock time taken by the program: 0.025275
# output2.txt file written successfully!
# Clock time taken by the program: 0.026085
# output2.txt file written successfully!
# Clock time taken by the program: 0.024948
# output2.txt file written successfully!
# Clock time taken by the program: 0.025573
# output2.txt file written successfully!
# Clock time taken by the program: 0.027647
# output2.txt file written successfully!
# Clock time taken by the program: 0.025283
# output2.txt file written successfully!
# Clock time taken by the program: 0.026419
# output2.txt file written successfully!
# Clock time taken by the program: 0.025037
# output2.txt file written successfully!
# Clock time taken by the program: 0.025826
# output2.txt file written successfully!
# Clock time taken by the program: 0.025367
# output2.txt file written successfully!
# Clock time taken by the program: 0.025921
# output2.txt file written successfully!
# Clock time taken by the program: 0.026482
# output2.txt file written successfully!
# Clock time taken by the program: 0.026316
# output2.txt file written successfully!
# Clock time taken by the program: 0.026984
# output2.txt file written successfully!
# Clock time taken by the program: 0.025356
# output2.txt file written successfully!
# Clock time taken by the program: 0.026022
# output2.txt file written successfully!
# Clock time taken by the program: 0.026637
# output2.txt file written successfully!
# Clock time taken by the program: 0.025881
# output2.txt file written successfully!
# Clock time taken by the program: 0.026981
# output2.txt file written successfully!
# Clock time taken by the program: 0.026160
# output2.txt file written successfully!
# Clock time taken by the program: 0.025975
# output2.txt file written successfully!
# Clock time taken by the program: 0.033840
# output2.txt file written successfully!
# Clock time taken by the program: 0.026168
# output2.txt file written successfully!
# Clock time taken by the program: 0.026735
# output2.txt file written successfully!
# Clock time taken by the program: 0.027074
# output2.txt file written successfully!
# ...
# Clock time taken by the program: 0.029710
# output2.txt file written successfully!
# Clock time taken by the program: 0.019650
# output2.txt file written successfully!
# Clock time taken by the program: 0.024111
# output2.txt file written successfully!
# Clock time taken by the program: 0.017027
# output2.txt file written successfully!
# Clock time taken by the program: 0.019455
# output2.txt file written successfully!
# Clock time taken by the program: 0.017684
# output2.txt file written successfully!
# Clock time taken by the program: 0.028170
# output2.txt file written successfully!
# Clock time taken by the program: 0.018762
# output2.txt file written successfully!
# Clock time taken by the program: 0.022303
# output2.txt file written successfully!
# Clock time taken by the program: 0.022322
# output2.txt file written successfully!
# Clock time taken by the program: 0.020424
# output2.txt file written successfully!
# Clock time taken by the program: 0.017522
# output2.txt file written successfully!
# Clock time taken by the program: 0.034886
# output2.txt file written successfully!
# Clock time taken by the program: 0.031612
# output2.txt file written successfully!
# Clock time taken by the program: 0.031417
# output2.txt file written successfully!
# Clock time taken by the program: 0.031690
# output2.txt file written successfully!
# Clock time taken by the program: 0.029769
# output2.txt file written successfully!
# Clock time taken by the program: 0.028830
# output2.txt file written successfully!
# Clock time taken by the program: 0.026151
# output2.txt file written successfully!
# Clock time taken by the program: 0.022197
# output2.txt file written successfully!
# Clock time taken by the program: 0.024837
# output2.txt file written successfully!
# Clock time taken by the program: 0.024815
# output2.txt file written successfully!
# Clock time taken by the program: 0.017877
# output2.txt file written successfully!
# Clock time taken by the program: 0.027228
# output2.txt file written successfully!
# Clock time taken by the program: 0.024991
# output2.txt file written successfully!
# Clock time taken by the program: 0.018413
# output2.txt file written successfully!
# Clock time taken by the program: 0.018446
# output2.txt file written successfully!
# Clock time taken by the program: 0.026021
# output2.txt file written successfully!
# Clock time taken by the program: 0.025840
# output2.txt file written successfully!
# Clock time taken by the program: 0.021698
# output2.txt file written successfully!
# Clock time taken by the program: 0.017009
# output2.txt file written successfully!
# Clock time taken by the program: 0.017479
# output2.txt file written successfully!
# Clock time taken by the program: 0.021940
# output2.txt file written successfully!
# Clock time taken by the program: 0.026931
# output2.txt file written successfully!
# Clock time taken by the program: 0.019705
# output2.txt file written successfully!
# Clock time taken by the program: 0.035260
# output2.txt file written successfully!
# Clock time taken by the program: 0.023016
# output2.txt file written successfully!
# Clock time taken by the program: 0.017489
# output2.txt file written successfully!
# Clock time taken by the program: 0.032714
# output2.txt file written successfully!
# Clock time taken by the program: 0.030579
# output2.txt file written successfully!
# Clock time taken by the program: 0.017698
# output2.txt file written successfully!
# Clock time taken by the program: 0.019040
# output2.txt file written successfully!
# Clock time taken by the program: 0.018335
# output2.txt file written successfully!
# Clock time taken by the program: 0.028602
# output2.txt file written successfully!
# Clock time taken by the program: 0.031147
# output2.txt file written successfully!
# Clock time taken by the program: 0.019266
# output2.txt file written successfully!
# Clock time taken by the program: 0.022081
# output2.txt file written successfully!
# Clock time taken by the program: 0.018001
# output2.txt file written successfully!
# Clock time taken by the program: 0.023305
# output2.txt file written successfully!
# Clock time taken by the program: 0.018130
# output2.txt file written successfully!
# Clock time taken by the program: 0.028696
# output2.txt file written successfully!
# Clock time taken by the program: 0.029927
# output2.txt file written successfully!
# Clock time taken by the program: 0.019768
# output2.txt file written successfully!
# Clock time taken by the program: 0.028220
# output2.txt file written successfully!
# Clock time taken by the program: 0.032647
# output2.txt file written successfully!
# Clock time taken by the program: 0.022760
# output2.txt file written successfully!
# Clock time taken by the program: 0.018230
# output2.txt file written successfully!
# Clock time taken by the program: 0.017986
# output2.txt file written successfully!
# Clock time taken by the program: 0.032072
# output2.txt file written successfully!
# Clock time taken by the program: 0.021455
# output2.txt file written successfully!
# Clock time taken by the program: 0.025383
# output2.txt file written successfully!
# Clock time taken by the program: 0.023096
# output2.txt file written successfully!
# Clock time taken by the program: 0.023369
# output2.txt file written successfully!
# Clock time taken by the program: 0.020289
# output2.txt file written successfully!
# Clock time taken by the program: 0.020238
# output2.txt file written successfully!
# Clock time taken by the program: 0.021352
# output2.txt file written successfully!
# Clock time taken by the program: 0.024624
# output2.txt file written successfully!
# Clock time taken by the program: 0.027720
# output2.txt file written successfully!
# Clock time taken by the program: 0.032051
# output2.txt file written successfully!
# Clock time taken by the program: 0.022397
# output2.txt file written successfully!
# Clock time taken by the program: 0.027746
# output2.txt file written successfully!
# Clock time taken by the program: 0.022388
# output2.txt file written successfully!
# Clock time taken by the program: 0.018738
# output2.txt file written successfully!
# Clock time taken by the program: 0.018156
# output2.txt file written successfully!
# Clock time taken by the program: 0.032680
# output2.txt file written successfully!
# Clock time taken by the program: 0.028864
# output2.txt file written successfully!
# Clock time taken by the program: 0.026204
# output2.txt file written successfully!
# Clock time taken by the program: 0.027457
# output2.txt file written successfully!
# Clock time taken by the program: 0.020225
# output2.txt file written successfully!
# Clock time taken by the program: 0.020173
# output2.txt file written successfully!
# Clock time taken by the program: 0.023958
# output2.txt file written successfully!
# Clock time taken by the program: 0.018442
# output2.txt file written successfully!
# Clock time taken by the program: 0.031543
# output2.txt file written successfully!
# Clock time taken by the program: 0.028154
# output2.txt file written successfully!
# Clock time taken by the program: 0.020604
# output2.txt file written successfully!
# Clock time taken by the program: 0.020417
# output2.txt file written successfully!
# Clock time taken by the program: 0.018796
# output2.txt file written successfully!
# Clock time taken by the program: 0.030786
# output2.txt file written successfully!
# Clock time taken by the program: 0.027676
# output2.txt file written successfully!
# Clock time taken by the program: 0.033796
# output2.txt file written successfully!
# Clock time taken by the program: 0.023129
# output2.txt file written successfully!
# Clock time taken by the program: 0.022563
# output2.txt file written successfully!
# Clock time taken by the program: 0.018463
# output2.txt file written successfully!
# Clock time taken by the program: 0.020290
# output2.txt file written successfully!
# Clock time taken by the program: 0.021953
# output2.txt file written successfully!
# Clock time taken by the program: 0.025548
# output2.txt file written successfully!
# Clock time taken by the program: 0.024408
# output2.txt file written successfully!
# Clock time taken by the program: 0.027169
# output2.txt file written successfully!
# Clock time taken by the program: 0.019010
# output2.txt file written successfully!
# Clock time taken by the program: 0.020160
# output2.txt file written successfully!
# Clock time taken by the program: 0.021167
# output2.txt file written successfully!
# Clock time taken by the program: 0.022185
# output2.txt file written successfully!
# Clock time taken by the program: 0.032728
# output2.txt file written successfully!
# Clock time taken by the program: 0.031693
# output2.txt file written successfully!
# Clock time taken by the program: 0.023217
# output2.txt file written successfully!
# Clock time taken by the program: 0.023204
# output2.txt file written successfully!
# Clock time taken by the program: 0.028265
# output2.txt file written successfully!
# Clock time taken by the program: 0.033027
# output2.txt file written successfully!
# Clock time taken by the program: 0.024332
# output2.txt file written successfully!
# Clock time taken by the program: 0.034883
# output2.txt file written successfully!
# Clock time taken by the program: 0.024221
# output2.txt file written successfully!
# Clock time taken by the program: 0.021078
# output2.txt file written successfully!
# Clock time taken by the program: 0.022112
# output2.txt file written successfully!
# Clock time taken by the program: 0.019942
# output2.txt file written successfully!
# Clock time taken by the program: 0.019858
# output2.txt file written successfully!
# Clock time taken by the program: 0.026530
# output2.txt file written successfully!
# Clock time taken by the program: 0.025923
# output2.txt file written successfully!
# Clock time taken by the program: 0.033425
# output2.txt file written successfully!
# Clock time taken by the program: 0.025290
# output2.txt file written successfully!
# Clock time taken by the program: 0.022157
# output2.txt file written successfully!
# Clock time taken by the program: 0.022341
# output2.txt file written successfully!
# Clock time taken by the program: 0.024767
# output2.txt file written successfully!
# Clock time taken by the program: 0.031280
# output2.txt file written successfully!
# Clock time taken by the program: 0.022470
# output2.txt file written successfully!
# Clock time taken by the program: 0.034462
# output2.txt file written successfully!
# Clock time taken by the program: 0.031529
# output2.txt file written successfully!
# Clock time taken by the program: 0.026001
# output2.txt file written successfully!
# Clock time taken by the program: 0.031417
# output2.txt file written successfully!
# Clock time taken by the program: 0.027604
# output2.txt file written successfully!
# Clock time taken by the program: 0.033252
# output2.txt file written successfully!
# Clock time taken by the program: 0.026320
# output2.txt file written successfully!
# Clock time taken by the program: 0.034830
# output2.txt file written successfully!
# Clock time taken by the program: 0.023682
# output2.txt file written successfully!
# Clock time taken by the program: 0.030092
# output2.txt file written successfully!
# Clock time taken by the program: 0.032636
# output2.txt file written successfully!
# Clock time taken by the program: 0.037708
# output2.txt file written successfully!
# Clock time taken by the program: 0.025752
# output2.txt file written successfully!
# Clock time taken by the program: 0.037854
# output2.txt file written successfully!
# Clock time taken by the program: 0.037869
# output2.txt file written successfully!
# Clock time taken by the program: 0.035573
# output2.txt file written successfully!
# Clock time taken by the program: 0.029864
# output2.txt file written successfully!
# Clock time taken by the program: 0.026712
# output2.txt file written successfully!
# Clock time taken by the program: 0.034771
# output2.txt file written successfully!
# Clock time taken by the program: 0.036603
# output2.txt file written successfully!
# Clock time taken by the program: 0.023436
# output2.txt file written successfully!
# Clock time taken by the program: 0.023103
# output2.txt file written successfully!
# Clock time taken by the program: 0.024632
# output2.txt file written successfully!
# Clock time taken by the program: 0.031001
# output2.txt file written successfully!
# Clock time taken by the program: 0.036243
# output2.txt file written successfully!
# Clock time taken by the program: 0.021437
# output2.txt file written successfully!
# Clock time taken by the program: 0.024144
# output2.txt file written successfully!
# Clock time taken by the program: 0.029933
# output2.txt file written successfully!
# Clock time taken by the program: 0.033509
# output2.txt file written successfully!
# Clock time taken by the program: 0.023689
# output2.txt file written successfully!
# Clock time taken by the program: 0.024660
# output2.txt file written successfully!
# Clock time taken by the program: 0.032028
# output2.txt file written successfully!
# Clock time taken by the program: 0.029687
# output2.txt file written successfully!
# Clock time taken by the program: 0.026470
# output2.txt file written successfully!
# Clock time taken by the program: 0.035564
# output2.txt file written successfully!
# Clock time taken by the program: 0.024895
# output2.txt file written successfully!
# Clock time taken by the program: 0.024596
# output2.txt file written successfully!
# Clock time taken by the program: 0.038572
# output2.txt file written successfully!
# Clock time taken by the program: 0.025027
# output2.txt file written successfully!
# Clock time taken by the program: 0.035350
# output2.txt file written successfully!
# Clock time taken by the program: 0.025739
# output2.txt file written successfully!
# Clock time taken by the program: 0.034221
# output2.txt file written successfully!
# Clock time taken by the program: 0.024672
# output2.txt file written successfully!
# Clock time taken by the program: 0.027568
# output2.txt file written successfully!
# Clock time taken by the program: 0.034093
# output2.txt file written successfully!
# Clock time taken by the program: 0.020642
# output2.txt file written successfully!
# Clock time taken by the program: 0.026919
# output2.txt file written successfully!
# Clock time taken by the program: 0.033021
# output2.txt file written successfully!
# Clock time taken by the program: 0.031277
# output2.txt file written successfully!
# Clock time taken by the program: 0.030934
# output2.txt file written successfully!
# Clock time taken by the program: 0.033540
# output2.txt file written successfully!
# Clock time taken by the program: 0.021179
# output2.txt file written successfully!
# Clock time taken by the program: 0.032875
# output2.txt file written successfully!
# Clock time taken by the program: 0.037385
# output2.txt file written successfully!
# Clock time taken by the program: 0.029309
# output2.txt file written successfully!
# Clock time taken by the program: 0.022398
# output2.txt file written successfully!
# Clock time taken by the program: 0.033385
# output2.txt file written successfully!
# Clock time taken by the program: 0.032349
# output2.txt file written successfully!
# Clock time taken by the program: 0.024699
# output2.txt file written successfully!
# Clock time taken by the program: 0.032365
# output2.txt file written successfully!
# Clock time taken by the program: 0.034718
# output2.txt file written successfully!
# Clock time taken by the program: 0.032039
# output2.txt file written successfully!
# Clock time taken by the program: 0.028279
# output2.txt file written successfully!
# Clock time taken by the program: 0.035444
# output2.txt file written successfully!
# Clock time taken by the program: 0.030463
# output2.txt file written successfully!
# Clock time taken by the program: 0.027244
# output2.txt file written successfully!
# Clock time taken by the program: 0.037248
# output2.txt file written successfully!
# Clock time taken by the program: 0.029879
# output2.txt file written successfully!
# Clock time taken by the program: 0.037737
# output2.txt file written successfully!
# Clock time taken by the program: 0.030046
# output2.txt file written successfully!
# Clock time taken by the program: 0.052670
# output2.txt file written successfully!
# Clock time taken by the program: 0.030315
# output2.txt file written successfully!
# Clock time taken by the program: 0.031060
# output2.txt file written successfully!
# Clock time taken by the program: 0.031646

# %% [markdown]
# ## Ploting input size VS time for algo b, O(nlog(n))

# %%
x = []
y = []
  
with open('plottime.csv','r') as csvfile:
    plots = csv.reader(csvfile, delimiter = ',')
    plots = list(plots)
    for row in plots[1:]:
        x.append(int(row[0]))
        y.append(float(row[3]))


plt.plot(x, y)
plt.title("Plot for Algo a")
plt.xlabel("Number of Students")
plt.ylabel("Time[sec]")
plt.show()

# %% [markdown]
# ## Running the Algo c for inputs from 100 to 1000

# %%
fp = open("plottime.csv", "w")
fp.write("n,k,Algo,time\n")
fp.close()

for n in range(100, 1000, 10):
    k = n//2
    fp = open("randominput.txt", "w")
    fp.write(str(str(n) + ' ' + str(k) + '\n'))
    res = generate_input(n, k)
    fp.writelines(res)
    fp.close()
    
    os.system("./app c randominput.txt")
# Out:
# output3.txt file written successfully!
# Clock time taken by the program: 0.000584
# output3.txt file written successfully!
# Clock time taken by the program: 0.000921
# output3.txt file written successfully!
# Clock time taken by the program: 0.000696
# output3.txt file written successfully!
# Clock time taken by the program: 0.000789
# output3.txt file written successfully!
# Clock time taken by the program: 0.000712
# output3.txt file written successfully!
# Clock time taken by the program: 0.000802
# output3.txt file written successfully!
# Clock time taken by the program: 0.000908
# output3.txt file written successfully!
# Clock time taken by the program: 0.000936
# output3.txt file written successfully!
# Clock time taken by the program: 0.000894
# output3.txt file written successfully!
# Clock time taken by the program: 0.001267
# output3.txt file written successfully!
# Clock time taken by the program: 0.001282
# output3.txt file written successfully!
# Clock time taken by the program: 0.001107
# output3.txt file written successfully!
# Clock time taken by the program: 0.000941
# output3.txt file written successfully!
# Clock time taken by the program: 0.001176
# output3.txt file written successfully!
# Clock time taken by the program: 0.001363
# output3.txt file written successfully!
# Clock time taken by the program: 0.001676
# output3.txt file written successfully!
# Clock time taken by the program: 0.001384
# output3.txt file written successfully!
# Clock time taken by the program: 0.000942
# output3.txt file written successfully!
# Clock time taken by the program: 0.001421
# output3.txt file written successfully!
# Clock time taken by the program: 0.001388
# output3.txt file written successfully!
# Clock time taken by the program: 0.001772
# output3.txt file written successfully!
# Clock time taken by the program: 0.001412
# output3.txt file written successfully!
# Clock time taken by the program: 0.001599
# output3.txt file written successfully!
# Clock time taken by the program: 0.001580
# output3.txt file written successfully!
# Clock time taken by the program: 0.001603
# output3.txt file written successfully!
# Clock time taken by the program: 0.001729
# output3.txt file written successfully!
# Clock time taken by the program: 0.001664
# output3.txt file written successfully!
# Clock time taken by the program: 0.002090
# output3.txt file written successfully!
# Clock time taken by the program: 0.001826
# output3.txt file written successfully!
# Clock time taken by the program: 0.001853
# output3.txt file written successfully!
# Clock time taken by the program: 0.001929
# output3.txt file written successfully!
# Clock time taken by the program: 0.001942
# output3.txt file written successfully!
# Clock time taken by the program: 0.002174
# output3.txt file written successfully!
# Clock time taken by the program: 0.002366
# output3.txt file written successfully!
# Clock time taken by the program: 0.002135
# output3.txt file written successfully!
# Clock time taken by the program: 0.002075
# output3.txt file written successfully!
# Clock time taken by the program: 0.002105
# output3.txt file written successfully!
# Clock time taken by the program: 0.002220
# output3.txt file written successfully!
# Clock time taken by the program: 0.002347
# output3.txt file written successfully!
# Clock time taken by the program: 0.002234
# output3.txt file written successfully!
# Clock time taken by the program: 0.002444
# output3.txt file written successfully!
# Clock time taken by the program: 0.002400
# output3.txt file written successfully!
# Clock time taken by the program: 0.002329
# output3.txt file written successfully!
# Clock time taken by the program: 0.002402
# output3.txt file written successfully!
# Clock time taken by the program: 0.001915
# output3.txt file written successfully!
# Clock time taken by the program: 0.002491
# output3.txt file written successfully!
# Clock time taken by the program: 0.002777
# output3.txt file written successfully!
# Clock time taken by the program: 0.002691
# output3.txt file written successfully!
# Clock time taken by the program: 0.002924
# output3.txt file written successfully!
# Clock time taken by the program: 0.002809
# output3.txt file written successfully!
# Clock time taken by the program: 0.002732
# output3.txt file written successfully!
# Clock time taken by the program: 0.002783
# output3.txt file written successfully!
# Clock time taken by the program: 0.002839
# output3.txt file written successfully!
# Clock time taken by the program: 0.002957
# output3.txt file written successfully!
# Clock time taken by the program: 0.003425
# output3.txt file written successfully!
# Clock time taken by the program: 0.002997
# output3.txt file written successfully!
# Clock time taken by the program: 0.003205
# output3.txt file written successfully!
# Clock time taken by the program: 0.003195
# output3.txt file written successfully!
# Clock time taken by the program: 0.003049
# output3.txt file written successfully!
# Clock time taken by the program: 0.003103
# output3.txt file written successfully!
# Clock time taken by the program: 0.002997
# output3.txt file written successfully!
# Clock time taken by the program: 0.003210
# output3.txt file written successfully!
# Clock time taken by the program: 0.003323
# output3.txt file written successfully!
# Clock time taken by the program: 0.003828
# output3.txt file written successfully!
# Clock time taken by the program: 0.003583
# output3.txt file written successfully!
# Clock time taken by the program: 0.003400
# output3.txt file written successfully!
# Clock time taken by the program: 0.003472
# output3.txt file written successfully!
# Clock time taken by the program: 0.003595
# output3.txt file written successfully!
# Clock time taken by the program: 0.003585
# output3.txt file written successfully!
# Clock time taken by the program: 0.003902
# output3.txt file written successfully!
# Clock time taken by the program: 0.003538
# output3.txt file written successfully!
# Clock time taken by the program: 0.003872
# output3.txt file written successfully!
# Clock time taken by the program: 0.003602
# output3.txt file written successfully!
# Clock time taken by the program: 0.003861
# output3.txt file written successfully!
# Clock time taken by the program: 0.004060
# output3.txt file written successfully!
# Clock time taken by the program: 0.003875
# output3.txt file written successfully!
# Clock time taken by the program: 0.004193
# output3.txt file written successfully!
# Clock time taken by the program: 0.003862
# output3.txt file written successfully!
# Clock time taken by the program: 0.004155
# output3.txt file written successfully!
# Clock time taken by the program: 0.004149
# output3.txt file written successfully!
# Clock time taken by the program: 0.004631
# output3.txt file written successfully!
# Clock time taken by the program: 0.004049
# output3.txt file written successfully!
# Clock time taken by the program: 0.004345
# output3.txt file written successfully!
# Clock time taken by the program: 0.004662
# output3.txt file written successfully!
# Clock time taken by the program: 0.004183
# output3.txt file written successfully!
# Clock time taken by the program: 0.004349
# output3.txt file written successfully!
# Clock time taken by the program: 0.004476
# output3.txt file written successfully!
# Clock time taken by the program: 0.004378
# output3.txt file written successfully!
# Clock time taken by the program: 0.004352
# output3.txt file written successfully!
# Clock time taken by the program: 0.004770

# %% [markdown]
# ## Ploting input size VS time for algo b, O(nlog(n))

# %%
x = []
y = []
  
with open('plottime.csv','r') as csvfile:
    plots = csv.reader(csvfile, delimiter = ',')
    plots = list(plots)
    for row in plots[1:]:
        x.append(int(row[0]))
        y.append(float(row[3]))


plt.plot(x, y)
plt.title("Plot for Algo a")
plt.xlabel("Number of Students")
plt.ylabel("Time[sec]")
plt.show()
